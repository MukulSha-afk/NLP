# %%
import nltk

# %%
#classification problem
##show comment on a video is positive or negative
## reviews--> eating eat, eaten ,[going,gone,goes]--->go

words = ["eating", "eats", "eaten", "writing", "writes", "programming", "programs","history","finnaly","finaliase"]

# %% [markdown]
# Porter Stemmer

# %%
from nltk.stem import PorterStemmer

# %%
stemming = PorterStemmer()

# %%
for word in words:
    print(word+"--->"+stemming.stem(word))
# Out:
# eating--->eat
# eats--->eat
# eaten--->eaten
# writing--->write
# writes--->write
# programming--->program
# programs--->program
# history--->histori
# finnaly--->finnali
# finaliase--->finalias

# %%
stemming.stem('congratulations')
# Out:
# 'congratul'

# %%
stemming.stem("setting")
# Out:
# 'set'

# %%
stemming.stem("blunket")
# Out:
# 'blunket'

# %% [markdown]
# RegexpStemmer class

# %%
from nltk.stem import RegexpStemmer

# %%
reg_stemmer=RegexpStemmer('ing$|s$|e$|able$', min=4)

# %%
reg_stemmer.stem('eating')
# Out:
# 'eat'

# %%
reg_stemmer.stem('ingeating')
# Out:
# 'ingeat'

# %% [markdown]
# ##snowball stemmer
# # gives batter accuracy

# %%
from nltk.stem import SnowballStemmer

# %%
snowballsstemmer=SnowballStemmer('english')

# %%
for word in words:
   print(word+"--->"+snowballsstemmer.stem(word))
# Out:
# eating--->eat
# eats--->eat
# eaten--->eaten
# writing--->write
# writes--->write
# programming--->program
# programs--->program
# history--->histori
# finnaly--->finnali
# finaliase--->finalias

# %%
stemming.stem(
