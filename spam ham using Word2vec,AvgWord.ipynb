# %%
import gensim
from gensim.models import Word2Vec , KeyedVectors

# %%
import gensim.downloader as api
wv = pd.read_csv('spamhamdata.csv')
vec_king = wv['king']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 import gensim.downloader as api
# ----> 2 wv = pd.read_csv('spamhamdata.csv')
#       3 vec_king = wv['king']
#
# NameError: name 'pd' is not defined

# %%
from nltk.tokenize import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
import re
import nltk
nltk.download('punkt')

# %%
corpus=[]
for i in range(0,len(ges)):
    review = re.sub('[^a-zA-z]',' ',ges['message'][i])
    review = review.lower()
    review = review.split()  
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    corpus.append(review)

# %%
words[]
for sent in corpus:
    sent_token = sent_tokenize(sent)
    for sent in sent_token:
        words.append(word_tokenize(sent))

# %%
words

# %%
import gensim

# %%
## Lets train the Word2Vec model from scratch
gensim.models.Word2Vec(words, min_count=1)

# %%
model.wv.index_to_key

# %%
model.corpus_count

# %%
model.epochs

# %%
model.wv.simillar_by_word('king')

# %%
model.wv['hello'].shape

# %%
def avg_word2vec(words):
    return np.mean([model.wv[word] for word in words if word in model.wv.index_to_key], axis=0)

# %%
# !pip install tqdm
from tqdm import tqdm

# %%
import numpy as np
x=[]
for i in tqdm(range(len(corpus))):
    x.append(avg_word2vec(corpus[i]))

# %%
len(x)

# %%
x_new.array(x)

# %%
x_new[0]

# %%
##dependent feature
##output feature
y=ges['label'].values
